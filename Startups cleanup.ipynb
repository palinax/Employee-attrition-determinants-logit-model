# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
event_appearances = pd.read_csv('event_appearances.csv')

event_appearances.head()
# Out:
#                                    uuid  \
# 0  30c4023d-b694-4704-97d7-cd99cd06ecce
# 1  dffe0542-3dac-4228-a997-3eed42cbd67e
# 2  21884e6c-d097-4c54-8513-10536a0ea60d
# 3  c3782f8f-4684-47d6-8649-d0b3e1825eb5
# 4  55e2ee8b-b5b7-49d3-bd21-a63eedf6b7f2
#
#                                          name              type  \
# 0  Adobe MAX 2014's sponsor - CDW Corporation  event_appearance
# 1        Adobe MAX 2014's sponsor - Microsoft  event_appearance
# 2          Adobe MAX 2014's sponsor - Twitter  event_appearance
# 3               Adobe MAX 2014's sponsor - HP  event_appearance
# 4            Adobe MAX 2014's sponsor - Intel  event_appearance
#
#                                            permalink  \
# 0  cdw-corporation-sponsor-adobe-max-2014104-los-...
# 1  microsoft-sponsor-adobe-max-2014104-los-angele...
# 2  twitter-sponsor-adobe-max-2014104-los-angeles-...
# 3  hewlett-packard-sponsor-adobe-max-2014104-los-...
# 4  intel-sponsor-adobe-max-2014104-los-angeles--5...
#
# ...

# %%
jobs = pd.read_csv('jobs.csv')

jobs.head()
# Out:
#                                    uuid  \
# 0  697b6934-fc1f-9d63-cfb2-1a10759b378e
# 1  b1de3765-442e-b556-9304-551c2a055901
# 2  1319cd30-f5e8-c700-0af6-64029c6f7124
# 3  27a252de-1ea8-c620-b2d4-5b889fa9b40f
# 4  5a802a79-229f-44ae-0aba-db330f10b67a
#
#                                         name type  \
# 0  Ben Elowitz Co-Founder and CEO @ Wetpaint  job
# 1     Kevin Flaherty VP Marketing @ Wetpaint  job
# 2       Raju Vegesna Chief Evangelist @ Zoho  job
# 3   Ian Wenig VP Business Development @ Zoho  job
# 4                     Jay Adelson CEO @ Digg  job
#
#                                      permalink  \
# 0     ben-elowitz-executive-wetpaint--697b6934
# 1  kevin-flaherty-executive-wetpaint--b1de3765
# 2         raju-vegesna-employee-zoho--1319cd30
# 3           ian-wenig-executive-zoho--27a252de
# 4         jay-adelson-executive-digg--5a802a79
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/job/ben-elowitz-exe...   NaN
# ...

# %%
investment_partners = pd.read_csv('investment_partners.csv')

investment_partners.head()
# Out:
#                                    uuid  \
# 0  524986f0-3049-54a4-fa72-f60897a5e61d
# 1  524986f0-3049-54a4-fa72-f60897a5e61d
# 2  6556ab92-6465-25aa-1ffc-7f8b4b09a476
# 3  0216e06a-61f8-9cf1-19ba-20811229c53e
# 4  dadd7d86-520d-5e35-3033-fc1d8792ab91
#
#                                                 name        type  \
# 0                Accel investment in Series A - Meta  investment
# 1                Accel investment in Series A - Meta  investment
# 2             Greylock investment in Series B - Meta  investment
# 3  Meritech Capital Partners investment in Series...  investment
# 4  Trinity Ventures investment in Series B - Phot...  investment
#
#                                            permalink  \
# 0  accel-invested-in-facebook-series-a--d950d7a5-...
# 1  accel-invested-in-facebook-series-a--d950d7a5-...
# 2  greylock-invested-in-facebook-series-b--6fae39...
# 3  meritech-capital-partners-invested-in-facebook...
# 4  trinity-ventures-invested-in-photobucket-serie...
#
# ...

# %%
organizations_desc = pd.read_csv('organization_descriptions.csv')

organizations_desc.head()
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
#
#          permalink                                             cb_url  \
# 0         wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2             digg       https://www.crunchbase.com/organization/digg
# 3  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4         facebook   https://www.crunchbase.com/organization/facebook
#
#        rank           created_at           updated_at  \
# 0  180418.0  2007-05-25 13:51:27  2022-03-07 05:47:35
# ...

# %%
org_parents = pd.read_csv('org_parents.csv')

org_parents.head()
# Out:
#                                    uuid                   name          type  \
# 0  d70777cc-14bd-2416-0692-5a483781b78b  Fox Interactive Media  organization
# 1  3d9e4070-1a25-7491-d1a9-17bec9f6361b      Hutchison Whampoa  organization
# 2  f09c1228-2e7d-1889-6647-ba5021b2e4ea      CBS Entertainment  organization
# 3  91f5ca18-e026-9482-8e4f-22593943e0f5                  Plaxo  organization
# 4  fc89cfde-a28e-e12c-443c-edccb6c93fd4                AddThis  organization
#
#                    permalink  \
# 0      fox-interactive-media
# 1  hutchison-whampoa-limited
# 2                        cbs
# 3                      plaxo
# 4                    addthis
#
#                                               cb_url      rank  \
# 0  https://www.crunchbase.com/organization/fox-in...  189202.0
# 1  https://www.crunchbase.com/organization/hutchi...  227000.0
# 2        https://www.crunchbase.com/organization/cbs  190919.0
# 3      https://www.crunchbase.com/organization/plaxo  123076.0
# ...

# %%
import pandas as pd

organizations = pd.read_csv('organizations.csv')

organizations.head()
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
#
#          permalink                                             cb_url  \
# 0         wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2             digg       https://www.crunchbase.com/organization/digg
# 3  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4         facebook   https://www.crunchbase.com/organization/facebook
#
#        rank           created_at           updated_at  \
# 0  180418.0  2007-05-25 13:51:27  2022-03-07 05:47:35
# ...

# %%
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
import pandas as pd

degrees = pd.read_csv('degrees.csv')

degrees.head()
# Out:
#                                    uuid  \
# 0  205fdfd1-ecac-aa43-262f-219f11755f67
# 1  1a2ac288-eb99-3318-fde5-1517bc168f51
# 2  b978d338-7ccc-7469-5ce7-ef98c34155ad
# 3  d01cfaad-0ccc-631e-0382-1e507bf6ba04
# 4  16a607f5-8ab3-573e-8d09-57b3e352e1d3
#
#                                                 name    type  permalink  \
# 0         MS  Mass Communication @ Boston University  degree        NaN
# 1  BA  English, French @ Washington University in...  degree        NaN
# 2  MS  Internet Technology @ University of Greenwich  degree        NaN
# 3     BS  Computer Science @ Northeastern University  degree        NaN
# 4  BS  Computer Science @ Rochester Institute of ...  degree        NaN
#
#    cb_url  rank           created_at           updated_at  \
# 0     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:40:03
# 1     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:39:57
# 2     NaN   NaN  2008-02-19 23:40:40  2018-02-13 01:43:09
# ...

# %%
funding_rounds = pd.read_csv('funding_rounds.csv')

funding_rounds.head()
# Out:
#                                    uuid                    name  \
# 0  8a945939-18e0-cc9d-27b9-bf33817b2818      Angel Round - Meta
# 1  d950d7a5-79ff-fb93-ca87-13386b0e2feb         Series A - Meta
# 2  6fae3958-a001-27c0-fb7e-666266aedd78         Series B - Meta
# 3  bcd5a63d-ed99-6963-0dd2-e36f6582f846  Series B - Photobucket
# 4  60e6afd9-1215-465a-dd17-0ed600d4e29b         Series A - Geni
#
#             type                       permalink  \
# 0  funding_round        facebook-angel--8a945939
# 1  funding_round     facebook-series-a--d950d7a5
# 2  funding_round     facebook-series-b--6fae3958
# 3  funding_round  photobucket-series-b--bcd5a63d
# 4  funding_round         geni-series-a--60e6afd9
#
#                                               cb_url      rank  \
# 0  https://www.crunchbase.com/funding_round/faceb...  521406.0
# 1  https://www.crunchbase.com/funding_round/faceb...  303380.0
# 2  https://www.crunchbase.com/funding_round/faceb...  194527.0
# ...

# %%
funding_rounds.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'country_code', 'state_code', 'region', 'city',
#        'investment_type', 'announced_on', 'raised_amount_usd', 'raised_amount',
#        'raised_amount_currency_code', 'post_money_valuation_usd',
#        'post_money_valuation', 'post_money_valuation_currency_code',
#        'investor_count', 'org_uuid', 'org_name', 'lead_investor_uuids'],
#       dtype='object')

# %%
organizations['type'].unique()
# Out:
# array(['organization'], dtype=object)

# %%
people = pd.read_csv('people.csv')

people.head()
# Out:
#                                    uuid            name    type  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz  person
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  person
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna  person
# 3  6e1bca72-a865-b518-b305-31214ce2d1b0       Ian Wenig  person
# 4  3b598c59-7b6c-2d48-763c-da55bca77035      Owen Byrne  person
#
#         permalink                                            cb_url      rank  \
# 0     ben-elowitz     https://www.crunchbase.com/person/ben-elowitz   23265.0
# 1  kevin-flaherty  https://www.crunchbase.com/person/kevin-flaherty  375459.0
# 2    raju-vegesna    https://www.crunchbase.com/person/raju-vegesna   13800.0
# 3       ian-wenig       https://www.crunchbase.com/person/ian-wenig  212707.0
# 4      owen-byrne      https://www.crunchbase.com/person/owen-byrne  575544.0
#
#             created_at           updated_at first_name last_name  ...  \
# ...

# %%
people.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'first_name', 'last_name', 'gender', 'country_code',
#        'state_code', 'region', 'city', 'featured_job_organization_uuid',
#        'featured_job_organization_name', 'featured_job_title', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url'],
#       dtype='object')

# %%
organizations.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
#organizations.dtypes

# %%
companies = organizations

# %%
companies.dtypes
# Out:
# uuid                            object
# name                            object
# type                            object
# permalink                       object
# cb_url                          object
# rank                           float64
# created_at                      object
# updated_at                      object
# legal_name                      object
# roles                           object
# domain                          object
# homepage_url                    object
# country_code                    object
# state_code                      object
# region                          object
# city                            object
# address                         object
# postal_code                     object
# status                          object
# short_description               object
# category_list                   object
# category_groups_list            object
# num_funding_rounds             float64
# total_funding_usd              float64
# ...

# %%
#Missing data 
companies.isnull().mean() * 100
# Out:
# uuid                            0.000000
# name                            0.001159
# type                            0.000000
# permalink                       0.001376
# cb_url                          0.001340
# rank                            0.041288
# created_at                      0.000000
# updated_at                      0.000000
# legal_name                     55.311626
# roles                           0.909063
# domain                          3.537957
# homepage_url                    3.537921
# country_code                    9.119350
# state_code                     52.911446
# region                          9.119350
# city                            9.119350
# address                        38.565093
# postal_code                    40.595780
# status                          0.000000
# short_description               0.005867
# category_list                   6.772120
# category_groups_list            6.772120
# num_funding_rounds             89.870975
# ...

# %%
# Remove rows with NaT (missing) values in the 'founded_on' column
companies = companies.dropna(subset=['founded_on'])
len(companies)
# Out:
# 2161581

# %%
# Convert 'founded_on' to datetime, coercing invalid values to NaT
#companies.loc[:, 'founded_on'] = pd.to_datetime(companies['founded_on'].dt.date)
companies['founded_on'].head()
# Out:
# 0   2005-06-01
# 1   1996-03-17
# 2   2004-10-11
# 3   2004-01-01
# 4   2004-02-04
# Name: founded_on, dtype: datetime64[ns]

# %%
# Display the minimum and maximum 'founded_on' values
print("Minimum founded_on:", companies['founded_on'].min())
print("Maximum founded_on:", companies['founded_on'].max())
# Out:
# Minimum founded_on: 1678-01-01 00:00:00
# Maximum founded_on: 2023-04-22 00:00:00

# %%
#organizations['founded_on'].describe()
# Calculate the current date
#current_year = pd.Timestamp.now().year
# Calculate the difference in years between 'founded_on' and today
#companies['age'] = companies['founded_on'].apply(lambda x: current_year - x.year)

companies['employee_count'].unique()
# Out:
# array(['51-100', '10000+', '101-250', '11-50', '501-1000', 'unknown',
#        '1001-5000', '251-500', '1-10', '5001-10000'], dtype=object)

# %%
# Define your criteria for a startup
young_age = 5  # For example, companies less than 5 years old
min_funding = 100000  # For example, companies with at least $100,000 in funding

# Calculate age of the companies
companies['age'] = companies['age'] = companies['founded_on'].apply(lambda x: current_year - x.year)

# Filter the DataFrame based on the criteria

startups = companies[
    (companies['age'] <= young_age) &
    (companies['total_funding_usd'] >= min_funding) &
    (companies['employee_count'].isin(['51-100', '11-50']))
]

startups.head()
# Out:
#                                        uuid           name          type  \
# 713    97a755c0-53fb-1e67-d9a4-fa95e6c5d102   Servixer LLC  organization
# 832    fdd4bfe1-5f7b-e403-d100-91e9ec01f903      VoiceSell  organization
# 3528   080d922c-318d-5f55-6b7a-5cb1c7b410bc         Huddle  organization
# 6578   5e298e78-0999-fe40-4b90-c21ed1c90786     Fundamento  organization
# 10804  55471401-db75-b747-eb4c-439d8bd55108  Navio Systems  organization
#
#            permalink                                             cb_url  \
# 713       testfreaks  https://www.crunchbase.com/organization/testfr...
# 832        voicesell  https://www.crunchbase.com/organization/voicesell
# 3528          huddle     https://www.crunchbase.com/organization/huddle
# 6578          skillr     https://www.crunchbase.com/organization/skillr
# 10804  navio-systems  https://www.crunchbase.com/organization/navio-...
#
#            rank           created_at           updated_at  \
# ...

# %%
startups.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits', 'founding_year',
#        'age'],
#       dtype='object')
